# %%
import seaborn as sns
import matplotlib.pyplot as plt
from pylab import *
import numpy as np
import pandas as pd

# %%
iris=sns.load_dataset("iris")
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
setosa=iris.loc[iris.species=="setosa"]
virginica=iris.loc[iris.species=="virginica"]

# %%
sns.kdeplot(setosa.sepal_length, color="r", shade=True)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='Density'>

# %%
sns.histplot(iris.sepal_length, kde=True)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='Count'>

# %%
sns.histplot(iris.sepal_length, kde=True, color="r")
sns.histplot(iris.sepal_width, kde=True, color="k")
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='Count'>

# %%
sns.kdeplot(data=iris, x="sepal_length", y="sepal_width")
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.kdeplot(data=iris, x="sepal_length", y="sepal_width",  shade=True)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
# "scatter" | "kde" | "hist" | "hex" | "reg" | "resid" 
sns.jointplot(data=iris,x="sepal_length",y="sepal_width", kind="hex")

# %%
b

# %%
sns.pairplot(iris, hue="species", size=3)
# Out:
# A:\Anaconda_Python\lib\site-packages\seaborn\axisgrid.py:1912: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.boxplot(x="species", y="petal_length", data=iris)
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_length'>

# %%
sns.FacetGrid(iris, hue="species", size=7).map(sns.kdeplot, "petal_length").add_legend()
# Out:
# A:\Anaconda_Python\lib\site-packages\seaborn\axisgrid.py:316: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.FacetGrid(iris, hue="species", size=7).map(plt.scatter, "sepal_length","sepal_width").add_legend()
# Out:
# A:\Anaconda_Python\lib\site-packages\seaborn\axisgrid.py:316: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.factorplot("sepal_length",data=iris,hue="species",kind="count")
# Out:
# A:\Anaconda_Python\lib\site-packages\seaborn\categorical.py:3704: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# A:\Anaconda_Python\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#correlation matrix
sns.heatmap(iris.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(iris.corr(),annot=True, cmap="cubehelix_r")
# Out:
# <AxesSubplot:>
