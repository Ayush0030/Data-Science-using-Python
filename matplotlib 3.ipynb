# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %%
#plt.bar(x axis values, height, width, bottom, align)
fig=plt.figure(figsize=(6,4))
divya={'Python':4,
       'Data Science':2,
      'CyberSecurity':4,
      'Networking':2}
x=list(divya.keys())
print(x)
y=list(divya.values())
print(y)
plt.bar(x,y)
plt.show()
# Out:
# ['Python', 'Data Science', 'CyberSecurity', 'Networking']
# [4, 2, 4, 2]

# %%
fig=plt.figure(figsize=(6,4))
divya={'Python':4,
       'Data Science':2,
      'CyberSecurity':4,
      'Networking':2}
x=list(divya.keys())
print(x)
y=list(divya.values())
print(y)
plt.bar(x,y,color="red",width=0.3)
plt.xlabel("Divya Has Chosen these Courses at TCIL")
plt.ylabel("Number of months estimated for completion")
plt.show()
# Out:
# ['Python', 'Data Science', 'CyberSecurity', 'Networking']
# [4, 2, 4, 2]

# %%
fig=plt.subplots(figsize=(12,8))
bar_width=0.25
    IT=[121,300,111,132,122]
    ECE=[152,342,435,234,245]
    CSE=[134,332,236,44,334]


bar1=np.arange(len(IT)) 
#0,1,2,3,4
bar2=[x + bar_width for x in bar1]
bar3=[x + bar_width for x in bar2]

plt.bar(bar1,IT,width=bar_width,label="IT Values")
plt.bar(bar2,ECE,width=bar_width,label="ECE Values")
plt.bar(bar3,CSE,width=bar_width,label="CSE Values")
plt.legend()
plt.show()
# Out:
# 5

# %%
fig=plt.subplots(figsize=(12,8))
bar_width=0.25
IT=[121,300,111,132,122]
ECE=[152,342,435,234,245]
CSE=[134,332,236,44,334]


bar1=np.arange(len(IT)) 
#0,1,2,3,4
bar2=[x + bar_width for x in bar1]
bar3=[x + bar_width for x in bar2]

plt.bar(bar1,IT,width=bar_width,label="IT Values")
plt.bar(bar2,ECE,width=bar_width,label="ECE Values")
plt.bar(bar3,CSE,width=bar_width,label="CSE Values")


plt.xlabel('Enginnering Branches',fontsize=25,fontweight='bold')
plt.ylabel('Number if Graduates')
plt.legend()
plt.show()

# %%
Random_number=5
by=(200,112,213,234,123)
gl=(211,111,233,445,664)

a=(4,6,7,9,3)
b=(5,3,1,3,6)

array=np.arange(Random_number)

bar_width=0.25

fig=plt.subplots(figsize=(10,10))
bar1=plt.bar(array,by,yerr=a,label="by")
bar2=plt.bar(array,gl,bottom=by,yerr=b,label="gl")
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9cc3e309874b> in <module>
#       6 b=(5,3,1,3,6)
#       7
# ----> 8 array=np.arange(Random_number)
#       9
#      10 bar_width=0.25
#
# NameError: name 'np' is not defined

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np
import matplotlib.pyplot as plt

N = 5

boys = (20, 35, 30, 35, 27)
girls = (25, 32, 34, 20, 25)
boyStd = (2, 3, 4, 10, 2)
girlStd = (33, 5, 2, 3, 3)
ind = np.arange(N)
width = 0.35

fig = plt.subplots(figsize =(10, 7))
p1 = plt.bar(ind, boys, width, yerr = boyStd)
# yerr define the errorbar sizes
p2 = plt.bar(ind, girls, width,
			bottom = boys, yerr = girlStd)

plt.ylabel('Contribution')
plt.title('Contribution by the teams')
plt.xticks(ind, ('T1', 'T2', 'T3', 'T4', 'T5'))
plt.yticks(np.arange(0, 81, 10))
plt.legend((p1[0], p2[0]), ('boys', 'girls'))

plt.show()
