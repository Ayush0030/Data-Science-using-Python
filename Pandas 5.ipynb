# %%
import numpy as np
import pandas as pd

# %%
pwd
# Out:
# 'C:\\Users\\AYUSH DHIMAN'

# %%
df=pd.read_csv('100SalesRecords.csv')

# %%
df
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
# ...

# %%
new_df=df
type(new_df)
new_df.to_csv('Tammmana_new_csv',index=False)

# %%
pd.read_csv('Tammmana_new_csv')
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
# ...

# %%
excel2=pd.read_excel('Book1.xlsx',sheet_name="Sheet1")
excel2.to_excel('Tammana_excel_demo.xlsx',index=False,sheet_name="Sheet1")

# %%
pd.read_excel('Tammana_excel_demo.xlsx')
# Out:
#    Unnamed: 0   a   b   c   d
# 0           0   1   2   3   4
# 1           1   5   6   7   8
# 2           2   9  10  11  12
# 3           3  13  14  15  16
# 4           4  17  18  19  20

# %%
bank_data=pd.read_html('https://www.fdic.gov/resources/resolutions/bank-failures/failed-bank-list/')

# %%
type(bank_data)
bank_data[:]
# Out:
# [                             Bank Name               City State   Cert  \
#  0                    Almena State Bank             Almena    KS  15426
#  1           First City Bank of Florida  Fort Walton Beach    FL  16748
#  2                 The First State Bank      Barboursville    WV  14361
#  3                   Ericson State Bank            Ericson    NE  18265
#  4     City National Bank of New Jersey             Newark    NJ  21111
#  ..                                 ...                ...   ...    ...
#  558                 Superior Bank, FSB           Hinsdale    IL  32646
#  559                Malta National Bank              Malta    OH   6629
#  560    First Alliance Bank & Trust Co.         Manchester    NH  34264
#  561  National State Bank of Metropolis         Metropolis    IL   3815
#  562                   Bank of Honolulu           Honolulu    HI  21029
#
#                     Acquiring Institution       Closing Date
# ...

# %%
df.head()
# Out:
#                               Region                Country        Item Type  \
# 0              Australia and Oceania                 Tuvalu        Baby Food
# 1  Central America and the Caribbean                Grenada           Cereal
# 2                             Europe                 Russia  Office Supplies
# 3                 Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                 Sub-Saharan Africa                 Rwanda  Office Supplies
#
#   Sales Channel Order Priority  Order Date   Order ID   Ship Date  Units Sold  \
# 0       Offline              H   5/28/2010  669165933   6/27/2010        9925
# 1        Online              C   8/22/2012  963881480   9/15/2012        2804
# 2       Offline              L  05-02-2014  341417157  05-08-2014        1779
# 3        Online              C   6/20/2014  514321792  07-05-2014        8102
# 4       Offline              L  02-01-2013  115456712  02-06-2013        5062
#
# ...

# %%
df.tail()
# Out:
#                 Region       Country      Item Type Sales Channel  \
# 95  Sub-Saharan Africa          Mali        Clothes        Online
# 96                Asia      Malaysia         Fruits       Offline
# 97  Sub-Saharan Africa  Sierra Leone     Vegetables       Offline
# 98       North America        Mexico  Personal Care       Offline
# 99  Sub-Saharan Africa    Mozambique      Household       Offline
#
#    Order Priority  Order Date   Order ID   Ship Date  Units Sold  Unit Price  \
# 95              M   7/26/2011  512878119  09-03-2011         888      109.28
# 96              L  11-11-2011  810711038  12/28/2011        6267        9.33
# 97              C  06-01-2016  728815257   6/29/2016        1485      154.06
# 98              M   7/30/2015  559427106  08-08-2015        5767       81.73
# 99              L  02-10-2012  665095412   2/15/2012        5367      668.27
#
#     Unit Cost  Total Revenue  Total Cost  Total Profit
# ...

# %%
df.sample(4)
# Out:
#                           Region     Country   Item Type Sales Channel  \
# 41  Middle East and North Africa  Azerbaijan   Cosmetics        Online
# 75                 North America      Mexico   Household       Offline
# 46                        Europe     Iceland   Cosmetics        Online
# 77                          Asia        Laos  Vegetables       Offline
#
#    Order Priority  Order Date   Order ID   Ship Date  Units Sold  Unit Price  \
# 41              M  02-06-2010  382392299   2/25/2010        7234      437.20
# 75              C  11-06-2014  986435210  12-12-2014        6954      668.27
# 46              C  12/31/2016  331438481  12/31/2016        8867      437.20
# 77              C   9/15/2011  789176547  10/23/2011        3732      154.06
#
#     Unit Cost  Total Revenue  Total Cost  Total Profit
# 41     263.33     3162704.80  1904929.22    1257775.58
# 75     502.54     4647149.58  3494663.16    1152486.42
# 46     263.33     3876652.40  2334947.11    1541705.29
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df['Sales Channel']
# Out:
# 0     Offline
# 1      Online
# 2     Offline
# 3      Online
# 4     Offline
#        ...
# 95     Online
# 96    Offline
# 97    Offline
# 98    Offline
# 99    Offline
# Name: Sales Channel, Length: 100, dtype: object

# %%
df['Region'].tail()
# Out:
# 95    Sub-Saharan Africa
# 96                  Asia
# 97    Sub-Saharan Africa
# 98         North America
# 99    Sub-Saharan Africa
# Name: Region, dtype: object

# %%
df.loc[99]
# Out:
# Region            Sub-Saharan Africa
# Country                   Mozambique
# Item Type                  Household
# Sales Channel                Offline
# Order Priority                     L
# Order Date                02-10-2012
# Order ID                   665095412
# Ship Date                  2/15/2012
# Units Sold                      5367
# Unit Price                    668.27
# Unit Cost                     502.54
# Total Revenue            3.58661e+06
# Total Cost               2.69713e+06
# Total Profit                  889473
# Name: 99, dtype: object

# %%
df.sample()
# Out:
#                 Region     Country  Item Type Sales Channel Order Priority  \
# 29  Sub-Saharan Africa  The Gambia  Household       Offline              L
#
#    Order Date   Order ID   Ship Date  Units Sold  Unit Price  Unit Cost  \
# 29  5/26/2012  886494815  06-09-2012        2370      668.27     502.54
#
#     Total Revenue  Total Cost  Total Profit
# 29      1583799.9   1191019.8      392780.1

# %%
df[['Region','Country','Order Priority']].iloc[29]
# Out:
# Region            Sub-Saharan Africa
# Country                   The Gambia
# Order Priority                     L
# Name: 29, dtype: object

# %%
df.head()
# Out:
#                               Region                Country        Item Type  \
# 0              Australia and Oceania                 Tuvalu        Baby Food
# 1  Central America and the Caribbean                Grenada           Cereal
# 2                             Europe                 Russia  Office Supplies
# 3                 Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                 Sub-Saharan Africa                 Rwanda  Office Supplies
#
#   Sales Channel Order Priority  Order Date   Order ID   Ship Date  Units Sold  \
# 0       Offline              H   5/28/2010  669165933   6/27/2010        9925
# 1        Online              C   8/22/2012  963881480   9/15/2012        2804
# 2       Offline              L  05-02-2014  341417157  05-08-2014        1779
# 3        Online              C   6/20/2014  514321792  07-05-2014        8102
# 4       Offline              L  02-01-2013  115456712  02-06-2013        5062
#
# ...

# %%
df[df['Units Sold']>5000]
# Out:
#                                Region                           Country  \
# 0               Australia and Oceania                            Tuvalu
# 3                  Sub-Saharan Africa             Sao Tome and Principe
# 4                  Sub-Saharan Africa                            Rwanda
# 7                  Sub-Saharan Africa                      Burkina Faso
# 8                  Sub-Saharan Africa             Republic of the Congo
# 9                  Sub-Saharan Africa                           Senegal
# 12                               Asia                        Bangladesh
# 13  Central America and the Caribbean                          Honduras
# 16                               Asia                         Sri Lanka
# 17                 Sub-Saharan Africa                          Cameroon
# 19              Australia and Oceania                        East Timor
# 20                             Europe                            Norway
# ...

# %%
#index column name

# %%
Dataframe_new=pd.read_csv('100SalesRecords.csv',header=None)

# %%
print(Dataframe_new)
# Out:
#                                     0                      1   \
# 0                               Region                Country
# 1                Australia and Oceania                 Tuvalu
# 2    Central America and the Caribbean                Grenada
# 3                               Europe                 Russia
# 4                   Sub-Saharan Africa  Sao Tome and Principe
# ..                                 ...                    ...
# 96                  Sub-Saharan Africa                   Mali
# 97                                Asia               Malaysia
# 98                  Sub-Saharan Africa           Sierra Leone
# 99                       North America                 Mexico
# 100                 Sub-Saharan Africa             Mozambique
#
#                   2              3               4           5          6   \
# 0          Item Type  Sales Channel  Order Priority  Order Date   Order ID
# ...

# %%
Dataframe_customHeader=pd.read_csv('100SalesRecords.csv')

print(Dataframe_customHeader)

new_header=['A','AA','AAA','AAAA','B','BB','BBB','BBBB','C','CC','CCC','CCCC','CCCCC','D']
print(new_header)
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
# ...

# %%
Dataframe_customHeader.to_csv('Custom_header_csv',index=False,header=new_header)
pd.read_csv('Custom_header_csv')
# Out:
#                                     A                     AA              AAA  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
# ...
