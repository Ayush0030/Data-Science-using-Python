# %%
import seaborn as sns
import matplotlib.pyplot as plt
from pylab import *
import numpy as np
import pandas as pd

# %%
p=pd.read_csv("googleplaystore.csv")
p.head()
x=np.random.randn(100)

# %%
ax=sns.distplot(x,rug=True,rug_kws={"color":"r"},kde_kws={"color":"k","lw":10},hist_kws={"color":"g","histtype":"step","linewidth":5,"alpha":1})
# Out:
# A:\Anaconda_Python\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# A:\Anaconda_Python\lib\site-packages\seaborn\distributions.py:2055: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(p.Rating)
# Out:
# A:\Anaconda_Python\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Rating', ylabel='Density'>

# %% [markdown]
# #####
# dark background,
# seaborn-dark,
# fast,
# ggplot,
# seaborn Muted,
# seaborn-ticks,
# seaborn-paper,
# colorblind,
# classic,
# grayscale,
# seaborn white,
# seaborn dark pallate,
# seaborn poster.....etc

# %%
plt.style.use("dark_background")
sns.distplot(p.Rating)
plt.title("App Rating between 0 to 5")
plt.show()
# Out:
# A:\Anaconda_Python\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.style.use("dark_background")
sns.distplot(p.Rating, color="r",bins=50)
plt.title("App Rating between 0 to 5",color='yellow')
plt.show()
# Out:
# A:\Anaconda_Python\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.style.use("ggplot")
sns.distplot(p.Rating, color="r",bins=50)
plt.title("App Rating between 0 to 5",color='yellow')
plt.show()
# Out:
# A:\Anaconda_Python\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
iris=sns.load_dataset("iris")
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris[iris.species=="setosa"]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 0            5.1          3.5           1.4          0.2  setosa
# 1            4.9          3.0           1.4          0.2  setosa
# 2            4.7          3.2           1.3          0.2  setosa
# 3            4.6          3.1           1.5          0.2  setosa
# 4            5.0          3.6           1.4          0.2  setosa
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa
# 11           4.8          3.4           1.6          0.2  setosa
# 12           4.8          3.0           1.4          0.1  setosa
# ...

# %%
setosa=iris.loc[iris.species=="setosa"]
virginica=iris.loc[iris.species=="virginica"]

# %%
setosa.sepal_length.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>
